# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Price": [20, 25, 30, 35, 40],
    "Bottles Sold": [120, 110, 90, 80, 70]
}

df = pd.DataFrame(data)
df
# Out:
#    Price  Bottles Sold
# 0     20           120
# 1     25           110
# 2     30            90
# 3     35            80
# 4     40            70

# %%
df["Revenue"] = df["Price"] * df["Bottles Sold"]
df
# Out:
#    Price  Bottles Sold  Revenue
# 0     20           120     2400
# 1     25           110     2750
# 2     30            90     2700
# 3     35            80     2800
# 4     40            70     2800

# %%
highest_revenue = df["Revenue"].max()
best_price = df.loc[df["Revenue"].idxmax(), "Price"]

print("Highest Revenue:", highest_revenue)
print("Best Price:", best_price)
# Out:
# Highest Revenue: 2800
# Best Price: 35

# %%
plt.figure(figsize=(6,4))
plt.bar(df["Price"].astype(str), df["Revenue"])
plt.title("Price vs Revenue")
plt.xlabel("Price (₹)")
plt.ylabel("Revenue (₹)")
plt.show()

# %%
print("Conclusion:")
print("The highest revenue is ₹2800, achieved at both ₹35 and ₹40.")
print("The shop owner should choose ₹35 because it generates the same maximum revenue while selling more bottles.")
